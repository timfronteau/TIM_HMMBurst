# %% [markdown]
# # Final: saving all HMM data, of which the states timecourses.

# %% [markdown]
# ## The libraries and methods we need:

# %%
import numpy as np
from loader import load_oneIC

# %%
from sklearn.decomposition import PCA
from hmmlearn import hmm
import scipy.signal as signal
import pickle

# %%
import matplotlib.pyplot as plt

# %%
import h5py

# %%
import xarray as xr

# %%
directory = "E:/timot/Documents/1 - Centrale Marseille/0.5 - Semestre S8/Stage/NIC_250819"
file = "FCK_LOCKED_IC_JYOTIKA_250819.mat"

path = f"{directory}/{file}"

mat_file = h5py.File(path, "r")
cells_refs = mat_file['FCK_LOCKED_IC_JYOTIKA']

n_IC = 4
n_subj = 23

# %% [markdown]
# ## Functions:

# %% [markdown]
# ### Cumputing functions:

# %%
# The embedx function copies the `x` array len(lags) times into `xe`
# with lags (i.e. time delays) between lags[0] and lags[-1] (we implement the time-delay array for the HMM).

def embedx(x, lags):
    
    Xe = np.zeros((x.shape[1], x.shape[0],  len(lags)))

    for l in range(len(lags)):
        Xe[:, :, l] = np.roll(x, lags[l], axis=0).swapaxes(0, 1)

    # Remove edges
    valid = np.ones((x.shape[0], 1), dtype=np.int8)
    valid[:np.abs(np.min(lags)), :] = 0
    valid[-np.abs(np.max(lags)):, :] = 0

    Xe = Xe[:, valid[:, 0] == 1, :]

    return Xe, valid


# The hmm_tde function finds parameters for the HMM,
# then uses them to determine the probability of presence of each found state over time.

def hmm_tde(data: np.array, lags, subj, IC, n_lags, n_states=3, n_iter=100, n_components=8, 
            covariance_type='full', model_type='GMMHMM', tol=0.01, n_mix=1, **kwargs):
    
    # Embed time serie
    xe, valid = embedx(data, lags)

    pca = PCA(n_components=n_components)
    y = pca.fit_transform(xe[0, :, :])
    
    if model_type=='GMMHMM':
        model = hmm.GMMHMM(n_components=n_states, n_iter=n_iter,
                            covariance_type=covariance_type, tol=tol, n_mix=n_mix, **kwargs)
        
    elif model_type=='GaussianHMM':
        model = hmm.GaussianHMM(n_components=n_states, n_iter=n_iter,
                            covariance_type=covariance_type, tol=tol, **kwargs)
        
    elif model_type=='MultinomialHMM':
        model = hmm.MultinomialHMM(n_components=n_states, n_iter=n_iter, tol=tol, **kwargs)
    
    else: 
        return "Non-exixting model_type. Please choose 'GMMHMM' or 'GaussianHMM' or 'MultinomialHMM'. default='GMMHMM'"
        
    model.fit(y)
    gamma = model.predict_proba(y)

    return gamma, model, xe

# %% [markdown]
# ### Plotting and saving functions:

# %%
def show_bigstates(
    gamma, n_states, xe, # the data we need for the plot
    
    subj, IC, # which IC of which subject is of interest here
    
    n_components, n_lags, covariance_type, model_type, n_mix, # infos we put in the .png name if we want to save it
):

    fig = plt.figure(figsize=(6, 6))
    plt.title('State Power Spectrum')
    max_power = np.zeros(n_states)
    psd_all = np.zeros((n_states, 196))
    for i in range(n_states):

        # Compute PSD separately for each lag
        tot = []
        for seg in xe[0, gamma[:, i]> .6, :].T:
            freqs, psd = signal.welch(x=seg, fs=256, nfft=1000)
            tot.append(psd)
        psd = np.mean(np.asarray(tot), 0)
        
        max_power[i] = np.amax(psd[80:])
        
        psd_all[i] = psd[:196]
        plt.plot(freqs[:196], psd_all[i])
    
    plt.ylabel('PSD')
    plt.xlabel('Frequencies (Hz)')
    plt.legend([f'state {i+1}' for i in range(n_states)], loc='upper right')
    plt.tight_layout()   

    plt.savefig(f'tde-hmm2/png_files/su{subj}IC{IC}All_lg{n_lags}co{n_components}st{n_states}'
                    +f'{n_mix}'+model_type+'_states-info.png', dpi=600)
    
    plt.close(fig)
    
    return psd_all, freqs[:196], max_power

# %%
def plot_hmm_over_bigtfr(   
    bigtime, bigtfr, gamma, lags, n_states, max_power, # the data we need for the plot
    
    subj, IC, # which IC of which subject is of interest here
    
    n_components, n_lags, covariance_type, model_type, n_mix, # infos we put in the .png name if we want to save it
):
    
    fig = plt.figure(figsize=(16*3, 5))

    # HMM states probability plot
    plt.subplot(211)
    plt.title('HMM States probability')
    time = bigtime[np.abs(np.min(lags)):-np.abs(np.max(lags))]

    burst = np.argmax(max_power) # this is the burst state index
    
    labels = ['']
    states = np.where([i not in [burst] for i in range(n_states)])[0] # the other indexes
    for i in states:
        plt.fill_between(x=time[:1793*3-60], y1=gamma[:1793*3-60, i], alpha=0.2)
        plt.xlim(0, 7*3)
        labels.append(f'state {i+1}')
    plt.plot(time[:1793*3-60], gamma[:1793*3-60, burst]>0.6, 'red')
    labels[0]=(f'burst state (state {burst+1})')
    plt.fill_between(x=time[:1793*3-60], y1=gamma[:1793*3-60, burst], alpha=0.2, color='red')
    plt.ylabel('State probability')
    plt.legend(labels, loc='upper left')

    # Time-frequency plot
    plt.subplot(212)

    plt.title('Wavelet transform')
    plt.imshow(bigtfr[0, :, :1793*3],
               aspect='auto', origin='lower', extent=[0, 7*3, 2, 50], cmap='RdBu_r')
    plt.xlabel('Time (s)')
    plt.ylabel('Frequencies (Hz)')
    plt.tight_layout()
    
    plt.savefig(f'tde-hmm2/png_files/su{subj}IC{IC}All_lg{n_lags}co{n_components}st{n_states}'
                    +f'{n_mix}'+model_type+'_hmm-tfr.png', dpi=600)
        
    plt.close(fig)

# %% [markdown]
# ## The routine:

# %% [markdown]
# #### Model and parameters:
# |_ 58delays x (7s x 256Hz x 10trials)   -----PCA-----> |_ 40components x (7s x 256Hz x 10trials) -----> |_ TDE-HMM
#                                                                                                         (
#                                                                                                         1 Gaussian/state,
#                                                                                                         3 states
#                                                                                                         )

# %%
# The parameters we change to hope for some results
lags = np.arange(-29, 29)
n_lags = lags.shape[0]
n_iter=100
n_states=3    # for the Hidden Markov Model
n_components=40     # For the principal component analysis
covariance_type='diag'
model_type='GMMHMM'
tol=0.01
n_mix=1

# %%
try:
    try:
        blabla
    except:
        print("aïe")
        raise
    print("Coucou")
except:
    print("Bravo !")
# Out:
# aïe
# Bravo !

# %%
import time as tm

# %%
subj_list = [i for i in range(2,9)] + [i for i in range(10,13)] + [14] + [i for i in range(16, n_subj+1)] 
                                                                            # All except subjects 1, 9, 13, 15
complete_time = tm.time()
for subj in subj_list:  
    for IC in range(1, n_IC+1): 
# for subj in [14]:
#     for IC in [1]:
        start_time = tm.time()
        try:
            print(f"---- SUBJECT{subj}, IC{IC} ----")
            # Loading all data for subject{subj}, IC{IC}
            data, n_trials = load_oneIC(mat_file, cells_refs, subj, IC)
                        
            # Finding and saving the model
            big_timecourse = np.concatenate([data[f'raw_timecourse_256Hz'][i] for i in range(n_trials)])
            x = big_timecourse.reshape(-1, 1)
            print("Computing the model")
            gamma, model, xe = hmm_tde(x, lags, subj, IC, n_lags, n_iter=n_iter, n_states=n_states, n_components=n_components, 
                                       covariance_type=covariance_type, model_type=model_type, tol=tol, n_mix=n_mix)
            print("Saving the model")
            with open(f"tde-hmm2/pkl_files/su{subj}IC{IC}All_lg{n_lags}co{n_components}st{n_states}"
                +f"{n_mix}"+model_type+"_model.pkl", "wb") as file: pickle.dump(model, file)
            print("Saving the states timecourse")
            gammaxr = xr.DataArray(
                gamma,
                dims=['time', 'states'],
                coords={
                    "subject": subj,
                    "IC": IC,
                },
            )
            ds = xr.Dataset({"states_timecourse_256Hz": gammaxr},)
            ds.to_netcdf(f"tde-hmm2/nc_files/su{subj}IC{IC}-states_timecourse_256Hz.nc")
            print("%s seconds" % (tm.time() - start_time))
            start_time = tm.time()
            
            # Saving the Power Spectral Density of each state
            print("Computing the PSD of each states and saving a plot")
            psd_all, freqs, max_power = show_bigstates(
                gamma, n_states, xe, # the data we need for the plot
                subj, IC, # which IC of which subject is of interest here
                n_components, n_lags, covariance_type, model_type, n_mix, # infos we put in the .png name if we want to save it
            )
            print("Saving the PSD of each state")
            psdxr = xr.DataArray(
                psd_all,
                dims=['states', 'power'],
                coords={
                    "subject": subj,
                    "IC": IC,
                },
            )
            # !!! ICI ajouter le freqs array dedans !!!
            ds = xr.Dataset({"states_psd": psdxr},)
            ds.to_netcdf(f"tde-hmm2/nc_files/su{subj}IC{IC}-states_psd.nc")

            # Saving a plot of probability timecourses of the states over the tfr 
            print("Saving a plot of the states timecourses over a plot of the tfr")
            time = data['time_axis']
            bigtime = np.concatenate([time+4+(7*i) for i in range(3)])
            bigtfr = np.concatenate([data[f'tfr_256Hz trial{i+1}'] for i in range(3)], axis=2)
            plot_hmm_over_bigtfr(   
                bigtime, bigtfr, gamma, lags, n_states, max_power, # the data we need for the plot
                subj, IC, # which IC of which subject is of interest here, how many trials
                n_components, n_lags, covariance_type, model_type, n_mix, # infos we put in the .png name if we want to save it
            )
            print("%s seconds" % (tm.time() - start_time))
            print(f"subj{subj}, IC{IC}: OK")
        except:
            print(f"subj{subj}, IC{IC}: NOT POSSIBLE")

sec_time = tm.time() - complete_time
hr_time = int(sec_time/3600)
sec_time = sec_time - (hr_time*3600)
mn_time = int(sec_time/60)
sec_time = sec_time - (mn_time*60)
print(f"{hr_time}h{mn_time}mn{sec_time}s")
# Out:
# ---- SUBJECT2, IC1 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 740.2580327987671 secondes
# Saving the model
# Saving the states timecourse
# 0.2864258289337158 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 197.40294528007507 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.022489070892334 seconds
# subj2, IC1: OK
# ---- SUBJECT2, IC2 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 503.2819197177887 secondes
# Saving the model
# Saving the states timecourse
# 0.2634603977203369 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 18.761027097702026 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.888735771179199 seconds
# subj2, IC2: OK
# ---- SUBJECT2, IC3 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 283.9537818431854 secondes
# Saving the model
# Saving the states timecourse
# 0.26000356674194336 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 19.02333116531372 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.866492509841919 seconds
# subj2, IC3: OK
# ---- SUBJECT2, IC4 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 513.5175077915192 secondes
# Saving the model
# Saving the states timecourse
# 0.2119617462158203 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 19.756784200668335 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.944642782211304 seconds
# subj2, IC4: OK
# ---- SUBJECT3, IC1 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 442.83305382728577 secondes
# Saving the model
# Saving the states timecourse
# 0.32134270668029785 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 19.676666259765625 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.05094575881958 seconds
# subj3, IC1: OK
# ---- SUBJECT3, IC2 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 472.66264390945435 secondes
# Saving the model
# Saving the states timecourse
# 0.5672392845153809 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 19.47416925430298 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.19770359992981 seconds
# subj3, IC2: OK
# ---- SUBJECT3, IC3 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 562.6206731796265 secondes
# Saving the model
# Saving the states timecourse
# 0.2653069496154785 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 19.891146183013916 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.838637351989746 seconds
# subj3, IC3: OK
# ---- SUBJECT3, IC4 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 812.8819596767426 secondes
# Saving the model
# Saving the states timecourse
# 0.30503177642822266 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 20.229644298553467 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.856757164001465 seconds
# subj3, IC4: OK
# ---- SUBJECT4, IC1 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 444.8785717487335 secondes
# Saving the model
# Saving the states timecourse
# 0.34720301628112793 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 22.481270790100098 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.034602165222168 seconds
# subj4, IC1: OK
# ---- SUBJECT4, IC2 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 710.3415689468384 secondes
# Saving the model
# Saving the states timecourse
# 0.6590213775634766 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 22.991422653198242 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.924347162246704 seconds
# subj4, IC2: OK
# ---- SUBJECT4, IC3 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 522.8060631752014 secondes
# Saving the model
# Saving the states timecourse
# 0.7668201923370361 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 22.965731620788574 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.939788818359375 seconds
# subj4, IC3: OK
# ---- SUBJECT4, IC4 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 593.233761548996 secondes
# Saving the model
# Saving the states timecourse
# 0.38062071800231934 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 22.299806356430054 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.176990032196045 seconds
# subj4, IC4: OK
# ---- SUBJECT5, IC1 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 630.2743353843689 secondes
# Saving the model
# Saving the states timecourse
# 0.31623125076293945 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 19.15798807144165 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.994269132614136 seconds
# subj5, IC1: OK
# ---- SUBJECT5, IC2 ----
# Loading the raw timecourse
# The independent component IC2 of the subject 5 is not in the .mat file.
# subj5, IC2: NOT POSSIBLE
# ---- SUBJECT5, IC3 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 308.52650356292725 secondes
# Saving the model
# Saving the states timecourse
# 0.26364922523498535 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 19.332146167755127 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.278829097747803 seconds
# subj5, IC3: OK
# ---- SUBJECT5, IC4 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 318.91684794425964 secondes
# Saving the model
# Saving the states timecourse
# 0.2580742835998535 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 18.862462520599365 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.910060405731201 seconds
# subj5, IC4: OK
# ---- SUBJECT6, IC1 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 488.4965476989746 secondes
# Saving the model
# Saving the states timecourse
# 0.6030323505401611 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 23.143654108047485 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.931891679763794 seconds
# subj6, IC1: OK
# ---- SUBJECT6, IC2 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 412.61844849586487 secondes
# Saving the model
# Saving the states timecourse
# 0.6263558864593506 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 22.97128129005432 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.051957130432129 seconds
# subj6, IC2: OK
# ---- SUBJECT6, IC3 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 428.52503061294556 secondes
# Saving the model
# Saving the states timecourse
# 0.36023974418640137 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 23.17232584953308 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.815839052200317 seconds
# subj6, IC3: OK
# ---- SUBJECT6, IC4 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 446.9971616268158 secondes
# Saving the model
# Saving the states timecourse
# 0.41019177436828613 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 24.19574809074402 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.059434175491333 seconds
# subj6, IC4: OK
# ---- SUBJECT7, IC1 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 598.7277116775513 secondes
# Saving the model
# Saving the states timecourse
# 0.37142157554626465 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 22.364134073257446 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.944289445877075 seconds
# subj7, IC1: OK
# ---- SUBJECT7, IC2 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 408.1838037967682 secondes
# Saving the model
# Saving the states timecourse
# 0.33501577377319336 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 22.054176568984985 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.991603136062622 seconds
# subj7, IC2: OK
# ---- SUBJECT7, IC3 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 576.1704790592194 secondes
# Saving the model
# Saving the states timecourse
# 0.2908782958984375 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 22.267326593399048 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.0111143589019775 seconds
# subj7, IC3: OK
# ---- SUBJECT7, IC4 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 460.51556301116943 secondes
# Saving the model
# Saving the states timecourse
# 0.33798813819885254 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 21.81720542907715 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.962209224700928 seconds
# subj7, IC4: OK
# ---- SUBJECT8, IC1 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 497.9141764640808 secondes
# Saving the model
# Saving the states timecourse
# 0.3179330825805664 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 22.292283058166504 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.224516868591309 seconds
# subj8, IC1: OK
# ---- SUBJECT8, IC2 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 454.4169375896454 secondes
# Saving the model
# Saving the states timecourse
# 0.36255693435668945 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 22.67825436592102 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.024200439453125 seconds
# subj8, IC2: OK
# ---- SUBJECT8, IC3 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 509.8177442550659 secondes
# Saving the model
# Saving the states timecourse
# 0.32287120819091797 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 22.608565092086792 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.8922319412231445 seconds
# subj8, IC3: OK
# ---- SUBJECT8, IC4 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 564.4680225849152 secondes
# Saving the model
# Saving the states timecourse
# 0.30716943740844727 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 22.573773860931396 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.979071140289307 seconds
# subj8, IC4: OK
# ---- SUBJECT10, IC1 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 498.5516519546509 secondes
# Saving the model
# Saving the states timecourse
# 0.7191803455352783 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 20.8063907623291 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.195109844207764 seconds
# subj10, IC1: OK
# ---- SUBJECT10, IC2 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 803.4940552711487 secondes
# Saving the model
# Saving the states timecourse
# 0.32976603507995605 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 21.738665103912354 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.036309719085693 seconds
# subj10, IC2: OK
# ---- SUBJECT10, IC3 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 431.93472027778625 secondes
# Saving the model
# Saving the states timecourse
# 0.2819671630859375 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 20.842617750167847 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.924769163131714 seconds
# subj10, IC3: OK
# ---- SUBJECT10, IC4 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 498.37109637260437 secondes
# Saving the model
# Saving the states timecourse
# 0.31514787673950195 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 20.904664993286133 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.940144062042236 seconds
# subj10, IC4: OK
# ---- SUBJECT11, IC1 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 763.2802152633667 secondes
# Saving the model
# Saving the states timecourse
# 0.3413279056549072 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 24.63133430480957 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.042008876800537 seconds
# subj11, IC1: OK
# ---- SUBJECT11, IC2 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 448.4229772090912 secondes
# Saving the model
# Saving the states timecourse
# 0.8135881423950195 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 24.978355884552002 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.016299247741699 seconds
# subj11, IC2: OK
# ---- SUBJECT11, IC3 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 358.751837015152 secondes
# Saving the model
# Saving the states timecourse
# 0.49211931228637695 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 25.046800136566162 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.013012647628784 seconds
# subj11, IC3: OK
# ---- SUBJECT11, IC4 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 490.22990918159485 secondes
# Saving the model
# Saving the states timecourse
# 0.44419145584106445 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 24.7831552028656 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.985428094863892 seconds
# subj11, IC4: OK
# ---- SUBJECT12, IC1 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 483.1323096752167 secondes
# Saving the model
# Saving the states timecourse
# 0.5399916172027588 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 18.352588415145874 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.017109394073486 seconds
# subj12, IC1: OK
# ---- SUBJECT12, IC2 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 400.77861881256104 secondes
# Saving the model
# Saving the states timecourse
# 0.30440354347229004 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 18.429354190826416 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.95625376701355 seconds
# subj12, IC2: OK
# ---- SUBJECT12, IC3 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 374.5434846878052 secondes
# Saving the model
# Saving the states timecourse
# 0.5832645893096924 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 18.355950117111206 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.8703553676605225 seconds
# subj12, IC3: OK
# ---- SUBJECT12, IC4 ----
# Loading the raw timecourse
# The independent component IC4 of the subject 12 is not in the .mat file.
# subj12, IC4: NOT POSSIBLE
# ---- SUBJECT14, IC1 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 519.1890592575073 secondes
# Saving the model
# Saving the states timecourse
# 0.6152503490447998 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 21.133020639419556 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.0578203201293945 seconds
# subj14, IC1: OK
# ---- SUBJECT14, IC2 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 423.3382935523987 secondes
# Saving the model
# Saving the states timecourse
# 0.5728476047515869 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 21.488929271697998 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.148808002471924 seconds
# subj14, IC2: OK
# ---- SUBJECT14, IC3 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 414.1392869949341 secondes
# Saving the model
# Saving the states timecourse
# 0.25389647483825684 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 24.623655796051025 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 9.723016262054443 seconds
# subj14, IC3: OK
# ---- SUBJECT14, IC4 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 423.0416123867035 secondes
# Saving the model
# Saving the states timecourse
# 0.7202243804931641 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 21.722411155700684 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.076582908630371 seconds
# subj14, IC4: OK
# ---- SUBJECT16, IC1 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 856.2510008811951 secondes
# Saving the model
# Saving the states timecourse
# 0.6012575626373291 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 23.50079345703125 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.261591911315918 seconds
# subj16, IC1: OK
# ---- SUBJECT16, IC2 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 658.3692061901093 secondes
# Saving the model
# Saving the states timecourse
# 0.6045398712158203 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 24.30652904510498 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.090539932250977 seconds
# subj16, IC2: OK
# ---- SUBJECT16, IC3 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 679.4189453125 secondes
# Saving the model
# Saving the states timecourse
# 0.5812597274780273 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 24.044248342514038 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.942365884780884 seconds
# subj16, IC3: OK
# ---- SUBJECT16, IC4 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 779.4145128726959 secondes
# Saving the model
# Saving the states timecourse
# 0.7565162181854248 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 24.27684473991394 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.021777391433716 seconds
# subj16, IC4: OK
# ---- SUBJECT17, IC1 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 888.1509854793549 secondes
# Saving the model
# Saving the states timecourse
# 0.6821279525756836 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 24.137001276016235 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.049454927444458 seconds
# subj17, IC1: OK
# ---- SUBJECT17, IC2 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 606.9738354682922 secondes
# Saving the model
# Saving the states timecourse
# 0.673961877822876 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 24.446516752243042 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.029533386230469 seconds
# subj17, IC2: OK
# ---- SUBJECT17, IC3 ----
# Loading the raw timecourse
# The independent component IC3 of the subject 17 is not in the .mat file.
# subj17, IC3: NOT POSSIBLE
# ---- SUBJECT17, IC4 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 856.9456679821014 secondes
# Saving the model
# Saving the states timecourse
# 0.6087312698364258 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 23.91074776649475 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.965224742889404 seconds
# subj17, IC4: OK
# ---- SUBJECT18, IC1 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 488.25413274765015 secondes
# Saving the model
# Saving the states timecourse
# 0.6976118087768555 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 25.474734783172607 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.058546543121338 seconds
# subj18, IC1: OK
# ---- SUBJECT18, IC2 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 897.2610282897949 secondes
# Saving the model
# Saving the states timecourse
# 0.961470365524292 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 25.45550012588501 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.082846403121948 seconds
# subj18, IC2: OK
# ---- SUBJECT18, IC3 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 495.10661911964417 secondes
# Saving the model
# Saving the states timecourse
# 0.8382978439331055 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 25.84679388999939 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.991721153259277 seconds
# subj18, IC3: OK
# ---- SUBJECT18, IC4 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 676.5535976886749 secondes
# Saving the model
# Saving the states timecourse
# 0.6360130310058594 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 25.52512240409851 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.940864086151123 seconds
# subj18, IC4: OK
# ---- SUBJECT19, IC1 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 470.01688528060913 secondes
# Saving the model
# Saving the states timecourse
# 0.7687475681304932 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 25.651889085769653 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.03367018699646 seconds
# subj19, IC1: OK
# ---- SUBJECT19, IC2 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 725.9442851543427 secondes
# Saving the model
# Saving the states timecourse
# 0.7496912479400635 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 25.786588668823242 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.9531731605529785 seconds
# subj19, IC2: OK
# ---- SUBJECT19, IC3 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 650.260466337204 secondes
# Saving the model
# Saving the states timecourse
# 0.7835180759429932 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 25.743679523468018 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 8.985430717468262 seconds
# subj19, IC3: OK
# ---- SUBJECT19, IC4 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 867.9993853569031 secondes
# Saving the model
# Saving the states timecourse
# 0.7714805603027344 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 26.091794729232788 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.029655694961548 seconds
# subj19, IC4: OK
# ---- SUBJECT20, IC1 ----
# Loading the raw timecourse
# The independent component IC1 of the subject 20 is not in the .mat file.
# subj20, IC1: NOT POSSIBLE
# ---- SUBJECT20, IC2 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 828.1742765903473 secondes
# Saving the model
# Saving the states timecourse
# 0.6044611930847168 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 21.67176580429077 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.085528135299683 seconds
# subj20, IC2: OK
# ---- SUBJECT20, IC3 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 576.2713952064514 secondes
# Saving the model
# Saving the states timecourse
# 0.30896687507629395 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 21.63404393196106 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.025707244873047 seconds
# subj20, IC3: OK
# ---- SUBJECT20, IC4 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 540.8757064342499 secondes
# Saving the model
# Saving the states timecourse
# 0.5956852436065674 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 21.796488523483276 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.9702370166778564 seconds
# subj20, IC4: OK
# ---- SUBJECT21, IC1 ----
# Loading the raw timecourse
# The independent component IC1 of the subject 21 is not in the .mat file.
# subj21, IC1: NOT POSSIBLE
# ---- SUBJECT21, IC2 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 816.4515769481659 secondes
# Saving the model
# Saving the states timecourse
# 0.5880327224731445 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 21.318509578704834 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.970113754272461 seconds
# subj21, IC2: OK
# ---- SUBJECT21, IC3 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 872.2994215488434 secondes
# Saving the model
# Saving the states timecourse
# 0.6571362018585205 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 21.143667697906494 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.947555780410767 seconds
# subj21, IC3: OK
# ---- SUBJECT21, IC4 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 757.441802740097 secondes
# Saving the model
# Saving the states timecourse
# 0.6464638710021973 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 21.494717121124268 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.992604732513428 seconds
# subj21, IC4: OK
# ---- SUBJECT22, IC1 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 890.3365771770477 secondes
# Saving the model
# Saving the states timecourse
# 0.6409270763397217 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 23.037968158721924 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.049365282058716 seconds
# subj22, IC1: OK
# ---- SUBJECT22, IC2 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 858.0119833946228 secondes
# Saving the model
# Saving the states timecourse
# 0.7107276916503906 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 23.64503049850464 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.130162239074707 seconds
# subj22, IC2: OK
# ---- SUBJECT22, IC3 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 859.3989276885986 secondes
# Saving the model
# Saving the states timecourse
# 0.639028787612915 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 23.387938022613525 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.177128314971924 seconds
# subj22, IC3: OK
# ---- SUBJECT22, IC4 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 698.3386564254761 secondes
# Saving the model
# Saving the states timecourse
# 0.8042125701904297 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 23.68128538131714 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.037163257598877 seconds
# subj22, IC4: OK
# ---- SUBJECT23, IC1 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 480.28299951553345 secondes
# Saving the model
# Saving the states timecourse
# 0.5912814140319824 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 21.904325246810913 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.005325794219971 seconds
# subj23, IC1: OK
# ---- SUBJECT23, IC2 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 380.9214472770691 secondes
# Saving the model
# Saving the states timecourse
# 0.5650646686553955 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 21.868200302124023 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 6.984791040420532 seconds
# subj23, IC2: OK
# ---- SUBJECT23, IC3 ----
# Loading the raw timecourse
# The independent component IC3 of the subject 23 is not in the .mat file.
# subj23, IC3: NOT POSSIBLE
# ---- SUBJECT23, IC4 ----
# Loading the raw timecourse
# Computing and loading the time-frequency wavelet transformation for 3 trials
# Computing the model
# 430.16886806488037 secondes
# Saving the model
# Saving the states timecourse
# 0.6363117694854736 seconds
# Computing the PSD of each states and saving a plot
# Saving the PSD of each state
# 21.62740182876587 seconds
# Saving a plot of the states timecourses over a plot of the tfr
# 7.025038957595825 seconds
# subj23, IC4: OK
