# %% [markdown]
# # Final: saving all HMM data, of which the states timecourses.

# %% [markdown]
# ## The libraries and methods we need:

# %%
import numpy as np
from loader import load_oneIC

# %%
import matplotlib.pyplot as plt

# %%
import h5py

# %%
import xarray as xr

# %%
directory = "E:/timot/Documents/1 - Centrale Marseille/0.5 - Semestre S8/Stage/NIC_250819"
file = "FCK_LOCKED_IC_JYOTIKA_250819.mat"

path = f"{directory}/{file}"

mat_file = h5py.File(path, "r")
cells_refs = mat_file['FCK_LOCKED_IC_JYOTIKA']

n_IC = 4
n_subj = 23

# %% [markdown]
# ## The routine:

# %%
# The parameters we change to hope for some results
lags = np.arange(-29, 29)
n_lags = lags.shape[0]
n_iter=100
n_states=6    # for the Hidden Markov Model
n_components=40     # For the principal component analysis
covariance_type='diag'
model_type='GMMHMM'
tol=0.01
n_mix=1

origin_dir = "tde-hmm2/6st_1IC/_Old_nc_files/"
target_dir = "tde-hmm2/6st_1IC/nc_files/"

# %%
freqs = np.arange(0, 50, 50/196)  # Found in file 9b_Visualisation.ipynb

# %%
# subj_list = [i for i in range(2,9)] + [i for i in range(10,13)] + [14] + [i for i in range(16, n_subj+1)] 
                                                                            # All except subjects 1, 9, 13, 15
    
subj_list = [i for i in range(2,8)]

for subj in subj_list:
    tcourses = []
    psds = []
    IC_list = []
    for IC in range(1, n_IC+1):
        try:
            print(f"---- SUBJECT{subj}, IC{IC} ----")

            data, n_trials = load_oneIC(mat_file, cells_refs, subj, IC, comp=False)
                        
            tcourse_disk = xr.open_dataset(origin_dir+f"su{subj}IC{IC}-states_timecourse_256Hz.nc")
            tcourse = np.concatenate(
                (np.zeros((29,n_states)), tcourse_disk["states_timecourse_256Hz"].values, np.zeros((28,n_states)))
            )
            
            psddata = xr.open_dataset(origin_dir+f"su{subj}IC{IC}-states_psd.nc")
            psds.append(
                psddata["states_psd"].values[np.newaxis]
            )
            
            t_len = data["time_axis"].shape[0]
            tcourse_trials = np.zeros((1, n_trials, t_len, n_states))
            for tr in range(n_trials):
                tcourse_trials[0, tr] = tcourse[tr*t_len:(tr+1)*t_len] 
            tcourses.append(tcourse_trials)
            IC_list.append(IC)
        except:
            print(f"subj{subj}, IC{IC}: NOT POSSIBLE")
    ds = xr.Dataset(
        {
            "states_timecourse": (("IC","trials","time", "states"), np.concatenate((tcourses))),
            "states_psd": (("IC", "states", "freq"), np.concatenate((psds))),
        },
        {
            "IC":IC_list,
            "time":data["time_axis"],
            "states":np.arange(n_states),
            "freq": freqs,
        }
    )
    ds.to_netcdf(target_dir+f"su{subj}-{n_states}states_data.nc")
# Out:
# ---- SUBJECT2, IC1 ----
# Loading the raw timecourse
# ---- SUBJECT2, IC2 ----
# Loading the raw timecourse
# ---- SUBJECT2, IC3 ----
# Loading the raw timecourse
# ---- SUBJECT2, IC4 ----
# Loading the raw timecourse
# ---- SUBJECT3, IC1 ----
# Loading the raw timecourse
# ---- SUBJECT3, IC2 ----
# Loading the raw timecourse
# ---- SUBJECT3, IC3 ----
# Loading the raw timecourse
# ---- SUBJECT3, IC4 ----
# Loading the raw timecourse
# ---- SUBJECT4, IC1 ----
# Loading the raw timecourse
# ---- SUBJECT4, IC2 ----
# Loading the raw timecourse
# ---- SUBJECT4, IC3 ----
# Loading the raw timecourse
# ---- SUBJECT4, IC4 ----
# Loading the raw timecourse
# ---- SUBJECT5, IC1 ----
# Loading the raw timecourse
# ---- SUBJECT5, IC2 ----
# Loading the raw timecourse
# The independent component IC2 of the subject 5 is not in the .mat file.
# subj5, IC2: NOT POSSIBLE
# ---- SUBJECT5, IC3 ----
# Loading the raw timecourse
# ---- SUBJECT5, IC4 ----
# Loading the raw timecourse
# ---- SUBJECT6, IC1 ----
# Loading the raw timecourse
# ---- SUBJECT6, IC2 ----
# Loading the raw timecourse
# ---- SUBJECT6, IC3 ----
# Loading the raw timecourse
# ---- SUBJECT6, IC4 ----
# Loading the raw timecourse
# ---- SUBJECT7, IC1 ----
# Loading the raw timecourse
# ---- SUBJECT7, IC2 ----
# Loading the raw timecourse
# ---- SUBJECT7, IC3 ----
# Loading the raw timecourse
# ---- SUBJECT7, IC4 ----
# Loading the raw timecourse
# ---- SUBJECT8, IC1 ----
# Loading the raw timecourse
# ---- SUBJECT8, IC2 ----
# Loading the raw timecourse
# subj8, IC2: NOT POSSIBLE
# ---- SUBJECT8, IC3 ----
# Loading the raw timecourse
# subj8, IC3: NOT POSSIBLE
# ---- SUBJECT8, IC4 ----
# Loading the raw timecourse
# subj8, IC4: NOT POSSIBLE
# ---- SUBJECT10, IC1 ----
# Loading the raw timecourse
# subj10, IC1: NOT POSSIBLE
# ---- SUBJECT10, IC2 ----
# Loading the raw timecourse
# subj10, IC2: NOT POSSIBLE
# ---- SUBJECT10, IC3 ----
# Loading the raw timecourse
# subj10, IC3: NOT POSSIBLE
# ---- SUBJECT10, IC4 ----
# Loading the raw timecourse
# subj10, IC4: NOT POSSIBLE
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-637f2e0639b1> in <module>
#      32     ds = xr.Dataset(
#      33         {
# ---> 34             "states_timecourse": (("IC","trials","time", "states"), np.concatenate((tcourses))),
#      35             "states_psd": (("IC", "states", "freq"), np.concatenate((psds))),
#      36         },
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: need at least one array to concatenate

# %%
for subj in subj_list:
    ds = xr.open_dataset(f"tde-hmm2/nc_files/su{subj}-3states_data.nc")
    print(f"----SUBJ{subj}----")
    print(ds.keys)
# Out:
# ----SUBJ3----
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:            (IC: 4, freq: 196, states: 3, time: 1793, trials: 673)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 1 2 3 4
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 ...>
# ----SUBJ4----
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:            (IC: 4, freq: 196, states: 3, time: 1793, trials: 760)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 1 2 3 4
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 ...>
# ----SUBJ5----
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:            (IC: 3, freq: 196, states: 3, time: 1793, trials: 638)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 1 3 4
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 ...>
# ----SUBJ6----
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:            (IC: 4, freq: 196, states: 3, time: 1793, trials: 781)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 1 2 3 4
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 ...>
# ----SUBJ7----
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:            (IC: 4, freq: 196, states: 3, time: 1793, trials: 743)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 1 2 3 4
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 ...>
# ----SUBJ8----
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:            (IC: 4, freq: 196, states: 3, time: 1793, trials: 766)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 1 2 3 4
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 ...>
# ----SUBJ10----
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:            (IC: 4, freq: 196, states: 3, time: 1793, trials: 705)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 1 2 3 4
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 ...>
# ----SUBJ11----
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:            (IC: 4, freq: 196, states: 3, time: 1793, trials: 834)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 1 2 3 4
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 ...>
# ----SUBJ12----
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:            (IC: 3, freq: 196, states: 3, time: 1793, trials: 616)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 1 2 3
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 ...>
# ----SUBJ14----
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:            (IC: 4, freq: 196, states: 3, time: 1793, trials: 723)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 1 2 3 4
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 ...>
# ----SUBJ16----
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:            (IC: 4, freq: 196, states: 3, time: 1793, trials: 805)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 1 2 3 4
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 ...>
# ----SUBJ17----
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:            (IC: 3, freq: 196, states: 3, time: 1793, trials: 818)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 1 2 4
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 ...>
# ----SUBJ18----
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:            (IC: 4, freq: 196, states: 3, time: 1793, trials: 860)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 1 2 3 4
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 ...>
# ----SUBJ19----
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:            (IC: 4, freq: 196, states: 3, time: 1793, trials: 860)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 1 2 3 4
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 ...>
# ----SUBJ20----
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:            (IC: 3, freq: 196, states: 3, time: 1793, trials: 732)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 2 3 4
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 ...>
# ----SUBJ21----
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:            (IC: 3, freq: 196, states: 3, time: 1793, trials: 723)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 2 3 4
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 ...>
# ----SUBJ22----
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:            (IC: 4, freq: 196, states: 3, time: 1793, trials: 793)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 1 2 3 4
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 ...>
# ----SUBJ23----
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:            (IC: 3, freq: 196, states: 3, time: 1793, trials: 739)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 1 2 4
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 ...>
