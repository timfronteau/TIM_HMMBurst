# %% [markdown]
# # Final: saving all HMM data, of which the states timecourses.

# %%
ds = xr.open_dataset(origin_dir+f"su{subj}-3states_data_v2.nc")

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:            (IC: 4, freq: 196, states: 3, time: 1793, trials: 675)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 1 2 3 4
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     frac_occ           (IC, time, states) float64 ...
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 ...

# %%
ds.keys
# Out:
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:            (IC: 4, freq: 196, states: 3, time: 1793, trials: 675)
# Coordinates:
#   * time               (time) float64 -4.0 -3.996 -3.992 ... 2.992 2.996 3.0
#   * freq               (freq) float64 0.0 0.2551 0.5102 ... 49.23 49.49 49.74
#   * IC                 (IC) int32 1 2 3 4
#   * states             (states) int32 1 2 3
# Dimensions without coordinates: trials
# Data variables:
#     frac_occ           (IC, time, states) float64 0.2915 0.3887 ... 0.2639
#     states_timecourse  (IC, trials, time, states) float64 ...
#     states_psd         (IC, states, freq) float64 0.006749 0.01575 ... 0.0008004>
